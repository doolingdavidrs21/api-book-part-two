# %% [markdown]
# https://learning.oreilly.com/library/view/hands-on-apis-for/9781098164409/ch09.html#id96
#
# In this chapter, you will learn best practices for consuming APIs and creating data analytics products using Jupyter Notebooks, a popular tool used by data scientists.
#
# Some of the most interesting work in custom metrics is happening in football, where the NFL has sponsored an annual analytics contest called the [Big Data Bowl](https://oreil.ly/5h1RE), where data students and professionals research and propose new metrics for prizes, job prospects, and the excitement of seeing their work included in TV broadcasts. It has a special track devoted to creating new custom metrics, such as converted tackle opportunity and path analysis via swarm-tackle accuracy (PASTA). Some have made their way into the broadcast booth, and more are on the way.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# base_ur l = "https://aws-api-container.xnkp6vj8k4sar.us-west-2.cs.amazonlightsail.com/"

# %% [markdown]
# need to run it locally, there are more endopints added:

# %% [markdown]
# ```bash
# .../api (main) $ fastapi run main.py
# ```

# %% [markdown]
# but on wsl need to go to this url: http://localhost:8000/docs
